# %% [markdown]
# #Tarea 2 - Funciones, Clases y Gráficos
#
# Para el correcto funcionamiento de las celdas adjuntas en este archivo, se debe importar el módulo funciones.py

# %% [markdown]
# El siguiente código, por medio de las librerias matplotlib, numpy y el módulo funciones, realiza la gráfica de la función $f(x) = x^2$, con $x \in [-10,10]$.

# %%
import matplotlib.pyplot as plt
import numpy as np
import funciones as fs

x = np.linspace(-10,10,100)
plt.plot(x,fs.f(x))
plt.show()

# %% [markdown]
# El siguiente código, por medio de las librerias plotly.graph, numpy y el módulo funciones, realiza la gráfica de la función $g(x) = \sin(x) \cdot \cos(y)$, con $x,y \in [-5,5]$.

# %%
import plotly.graph_objects as go
import numpy as np
import funciones as fs

x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
X,Y = np.meshgrid(x,y)
Z = fs.g(X,Y)
fig = go.Figure(data=[go.Surface(x=X,y=Y,z=Z,colorscale='Viridis')])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Anexos

# %% [markdown]
# El siguiente código aplica la clase Funcion creada en el módulo funciones.py para una función de dos variables.

# %%
from numpy import sin, cos
import funciones as fs

F = fs.Funcion("x**2+2*x+1+3*y",["x","y"])

x = float(input('Ingrese el valor de la variable x: '))
y = float(input('Ingrese el valor de la variable y: '))

resultado = F.evaluar(x,y)
print("La función ", F.expresion, " con variables ", F.variables, " al evaluarla en F(",x,",",y,") da como resultado ",resultado)
# Out:
# Ingrese el valor de la variable x: 4
# Ingrese el valor de la variable y: 6
# La función  x**2+2*x+1+3*y  con variables  ['x', 'y']  al evaluarla en F( 4.0 , 6.0 ) da como resultado  43.0
